# %%
import numpy as np
from matplotlib import pyplot as plt
import csv
from collections import Counter
import pandas as pd

#plt.style.use("fivethirtyeight")
df = pd.read_csv("school_census_data_18.csv")#, header = 0, usecols = ["Gender", "Handed", "Superpower"])
df.Handed
df.head()
df.tail(3)
df.sample(4)
df.Ageyears < 18
df[df.Ageyears < 18].sort_values(by="Ageyears").head(5)

# for row in df:
#     print(row)
# hand_count = Counter()
# for row in df:
#     hand_count.update("Handed")
    
#print(hand_count)
# handed = data["Handed"]
# gender = data["Gender"]

# handed_counter = Counter()

# for hand in handed:
#     handed_counter.update(handed)
        
# print(handed_counter)
# Out:
#    Country Region  DataYear  ClassGrade  Gender  Ageyears        Handed  \
# 35     USA     IL      2018          12  Female      15.0  Right-Handed
# 53     USA     MN      2018          12    Male      16.0  Right-Handed
# 76     USA     IL      2018          12    Male      16.0  Right-Handed
# 37     USA     FL      2018          12    Male      16.0  Right-Handed
# 67     USA     OK      2018          12  Female      16.0  Right-Handed
#
#    Height_cm Footlength_cm Armspan_cm  ...  Watching_TV_Hours Paid_Work_Hours  \
# 35       162            22        146  ...                2.0             0.0
# 53       175            25        178  ...                0.0            15.0
# 76       177            27        175  ...                0.0            16.0
# 37       181            27        183  ...               10.0            28.0
# 67       158            23        159  ...                7.0             0.0
#
# ...
