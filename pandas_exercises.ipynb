# %%
from pydataset import data
import pandas as pd
import numpy as np
from env import host, user, password

# %%
def dataframe_splain(dataframe, use_name='sample'):
    sample_size=min(11,len(dataframe))
    print(f'{use_name.upper()} DATA')
    if sample_size == 11:
        print(dataframe.sample(10))
    else:
        print(dataframe)
    print()
    print(f'{use_name} details{str(dataframe.shape)}')
    print(dataframe.dtypes)

# %%
mpg = data("mpg")
data("mpg", show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 1a. On average, which manufacturer has the best miles per gallon?

# %%
dataframe_splain(mpg, "mpg")
# Out:
# MPG DATA
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 120      hyundai              tiburon    2.7  2008    6    auto(l4)   f   17
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4   12
# 54         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4   14
# 73         dodge  ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4   13
# 164       subaru         forester awd    2.5  2008    4    auto(l4)   4   20
# 28     chevrolet             corvette    7.0  2008    8  manual(m6)   r   15
# 154       nissan       pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 70         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 218   volkswagen                jetta    2.5  2008    5    auto(s6)   f   21
# 176       toyota          4runner 4wd    3.4  1999    6    auto(l4)   4   15
#
#      hwy fl       class  average_mileage
# 120   24  r  subcompact             29.0
# ...

# %%
# This is wrong... go back and fix it
# If you have a groupby, you have to have an .agg
# The simplest .agg is count
# Use groupby and agg("mean")
mpg["average_mileage"] = (mpg.cty + mpg.hwy) / 2
best_average_mileage = mpg.groupby("manufacturer").count()
best_average_mileage = pd.DataFrame(mpg.groupby("manufacturer").average_mileage.agg("mean")).sort_values(by="average_mileage", ascending=False)
# best_average_mileage = mpg.sort_values(by="average_mileage", ascending=False)
best_average_mileage
# Out:
#               average_mileage
# manufacturer
# honda               28.500000
# volkswagen          25.074074
# hyundai             22.750000
# subaru              22.428571
# audi                22.027778
# toyota              21.720588
# pontiac             21.700000
# nissan              21.346154
# chevrolet           18.447368
# ford                16.680000
# mercury             15.625000
# jeep                15.562500
# dodge               15.540541
# lincoln             14.166667
# land rover          14.000000

# %% [markdown]
# 1b. How many different manufacturers are there?

# %%
#nunique can do this, too
#mpg.manufacturer.nunique()
num_of_manufacturers = len(mpg.manufacturer.unique())
num_of_manufacturers
# Out:
# 15

# %% [markdown]
# 1c. How many different models are there?

# %%
#nunique can do this, too 
#mpg.model.nunique()
num_of_models = len(mpg.model.unique())
num_of_models
# Out:
# 38

# %%
# something I was messing around with...
# models_by_manufacturer = mpg.manufacturer.value_counts()
# models_by_manufacturer

# %% [markdown]
# 1d. Do automatic or manual cars have better miles per gallon?

# %%
automatic_trans = mpg[mpg.trans.str.contains("auto")]
automatic_trans
# Out:
#     manufacturer                   model  displ  year  cyl     trans drv  cty  \
# 1           audi                      a4    1.8  1999    4  auto(l5)   f   18
# 4           audi                      a4    2.0  2008    4  auto(av)   f   21
# 5           audi                      a4    2.8  1999    6  auto(l5)   f   16
# 7           audi                      a4    3.1  2008    6  auto(av)   f   18
# 9           audi              a4 quattro    1.8  1999    4  auto(l5)   4   16
# 11          audi              a4 quattro    2.0  2008    4  auto(s6)   4   19
# 12          audi              a4 quattro    2.8  1999    6  auto(l5)   4   15
# 14          audi              a4 quattro    3.1  2008    6  auto(s6)   4   17
# 16          audi              a6 quattro    2.8  1999    6  auto(l5)   4   15
# 17          audi              a6 quattro    3.1  2008    6  auto(s6)   4   17
# 18          audi              a6 quattro    4.2  2008    8  auto(s6)   4   16
# ...

# %%
#automatic_trans.sort_values(by="average_mileage", ascending=False)
automatic_trans_mean = round(automatic_trans.average_mileage.mean())
automatic_trans_mean
# Out:
# 19

# %%
manual_trans = mpg[mpg.trans.str.contains("man")]
manual_trans_mean = round(manual_trans.average_mileage.mean())
manual_trans_mean
# Out:
# 22

# %%
#manual_trans.average_mileage.value_counts(ascending=False)

# %% [markdown]
# 2. Joining and Merging
#
# Copy the users and roles dataframes from the examples above. What do you think a right join would look like? An outer join? What happens if you drop the foreign keys from the dataframes and try to merge them?

# %%
# create dataframes
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})

# %%
# merge using how="right" We accept nulls/NaNs from the right table
pd.merge(
    users.rename(columns={"id": "user_id", "name": "username"}),
    roles.rename(columns={"name": "role_name"}),
    left_on="role_id", right_on="id", how="right")
# Out:
#    user_id username  role_id  id  role_name
# 0      1.0      bob      1.0   1      admin
# 1      2.0      joe      2.0   2     author
# 2      3.0    sally      3.0   3   reviewer
# 3      4.0     adam      3.0   3   reviewer
# 4      NaN      NaN      NaN   4  commenter

# %%
# merge using how="outer"
pd.merge(
    users.rename(columns={"id": "user_id", "name": "username"}),
    roles.rename(columns={"name": "role_name"}),
    left_on="role_id", right_on="id", how="outer")
# Out:
#    user_id username  role_id   id  role_name
# 0      1.0      bob      1.0  1.0      admin
# 1      2.0      joe      2.0  2.0     author
# 2      3.0    sally      3.0  3.0   reviewer
# 3      4.0     adam      3.0  3.0   reviewer
# 4      5.0     jane      NaN  NaN        NaN
# 5      6.0     mike      NaN  NaN        NaN
# 6      NaN      NaN      NaN  4.0  commenter

# %%
# merge dropping foreign keys
pd.merge(
    users.rename(columns={"id": "user_id", "name": "username"}),
    roles.rename(columns={"name": "role_name"}),
    left_on="role_id", right_on="id", how="right")

# %% [markdown]
# 3. Getting data from SQL databases
#
#     Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url formatted like in the examples in this lesson.
#
#     Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL and python/pandas code)

# %%
# create a function that produces the necessary connection string for communication
# between a SQL query and Pandas
def get_db_url(username, hostname, password, db_name):
    return f"mysql+pymysql://{user}:{password}@{host}/{db_name}"

# %% [markdown]
# -Use your function to obtain a connection to the employees database.

# %%
url = get_db_url(user, host, password, "employees")

# %% [markdown]
# -Once you have successfully run a query:

# %%
df_employees = pd.read_sql('SELECT * FROM employees', url)

# %% [markdown]
# -Intentionally make a typo in the database url. What kind of error message do you see?

# %% [markdown]
# -Intentionally make an error in your SQL query. What does the error message look like?

# %% [markdown]
# -Read the employees and titles tables into two separate dataframes

# %%
df_titles = pd.read_sql("SELECT * FROM titles", url)
df_titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# -Visualize the number of employees with each title.

# %%
sql ="""
SELECT title, count(*) as number
FROM titles
GROUP  BY title;
""" 
pd.read_sql(sql, url)
# Out:
#                 title  number
# 0  Assistant Engineer   15128
# 1            Engineer  115003
# 2             Manager      24
# 3     Senior Engineer   97750
# 4        Senior Staff   92853
# 5               Staff  107391
# 6    Technique Leader   15159

# %%
df_titles.groupby("title").count().emp_no
# Out:
# title
# Assistant Engineer     15128
# Engineer              115003
# Manager                   24
# Senior Engineer        97750
# Senior Staff           92853
# Staff                 107391
# Technique Leader       15159
# Name: emp_no, dtype: int64

# %% [markdown]
# -Join the employees and titles dataframes together.

# %% [markdown]
# -Visualize how frequently employees change titles.

# %% [markdown]
# -For each title, find the hire date of the employee that was hired most recently with that title.

# %% [markdown]
# -Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL and python/pandas code)
