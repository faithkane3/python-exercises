# %% [markdown]
# ## Exercises
#
# Do your work for this exercise in a jupyter notebook named 4.6.1_matplotlib_exercises.
#
# 1. Use matplotlib to plot the following equation:

# %% [markdown]
# y = $x^2$ - x + 2
#
# Add an anotation for the point 0, 0, the origin.

# %%
import matplotlib.pyplot as plt
import math
import random
import numpy as np
# %matplotlib inline

# %%
x = range(-10, 10, 1)
y = [i ** 2 - i + 2 for i in x]

plt.plot(x,y, c = "blueviolet")
plt.title("y = $x^2$ - x + 2")
plt.annotate('(0,0)', xy=(0, 0), xytext=(-3, 5),
             arrowprops={'facecolor': 'firebrick'})
plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y = √x
#
# y = $x^3$
#
# y = tan(x)
#
# y = $2^x$
#
# Note: You can use functions from the math module to help implement some of the equations above.

# %%
x = range(0,100, 1)
y = [math.sqrt(i) for i in x]
plt.plot(x,y)
plt.title("y = $\sqrt{x}$")
plt.show()

# %%
x = np.arange(-10,10,1)
y = [i ** 3 for i in x]

plt.plot(x,y, c="orange")
plt.title("y = $x^3$")
plt.show()

# %%
x = np.arange(-80,80, .1)
y = [math.tan(i) for i in x]
plt.plot(x,y, c="purple")

plt.title("y = tan(x)")
plt.show()

# %%
x = np.arange(0, 30)
y = [2 ** i for i in x]
plt.plot(x,y, c="red")

plt.title("y = $2^x$")
plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(10, 10))

n_rows = 2
n_cols = 2

# the first subplot
plt.subplot(n_rows, n_cols, 1)

x = range(0,100, 1)
y = [math.sqrt(i) for i in x]

plt.plot(x,y)
plt.title("y = $\sqrt{x}$")

# the second subplot
plt.subplot(n_rows, n_cols, 2)

x = np.arange(-10,10,1)
y = [i ** 3 for i in x]

plt.plot(x,y, c="orange")
plt.title("y = $x^3$")

# the third subplot
plt.subplot(n_rows, n_cols, 3)

x = np.arange(-80,80, .1)
y = [math.tan(i) for i in x]

plt.plot(x,y, c="purple")
plt.title("y = tan(x)")

# the fourth subplot
plt.subplot(n_rows, n_cols, 4)

x = np.arange(0, 30)
y = [2 ** i for i in x]

plt.plot(x,y, c="red")
plt.title("y = $2^x$")

plt.suptitle('Four in One')
plt.show()

# %% [markdown]
# Comine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend.

# %%
x = range(0,10)
y1 = [math.sqrt(i) for i in x]
y2 = [i ** 3 for i in x]
y3 = [math.tan(i) for i in x]
y4 = [2 ** i for i in x]

plt.plot(x,y1, c="blue", label='y = $\sqrt{x}$')
plt.plot(x,y2, c="yellow", label='y = $x^3$')
plt.plot(x,y3, c="purple", label='y = tan(x)')
plt.plot(x,y4, c="red", label='y = $2^x$')
plt.annotate('Check out this mess', xy=(4,150), xytext=(0, 200),
             arrowprops={'facecolor': 'firebrick'})
plt.legend(loc='upper left')
plt.xlabel('$x$')
plt.title("The Monster")
plt.show()
